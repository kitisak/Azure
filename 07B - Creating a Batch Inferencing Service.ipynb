# %% [markdown]
# # Creating a Batch Inferencing Service

# %% [markdown]
# ## Connect to Your Workspace

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.21.0 to work with mymachinelearningws

# %% [markdown]
# ## Train and Register a Model

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace = ws, name = "diabetes-training")
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: diabetes-training
# Loading Data...
# Training a decision tree model
# Accuracy: 0.888
# AUC: 0.8760833872331957
# Model trained and registered.

# %% [markdown]
# ## Generate and Upload Batch Data

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# aml_data - Default = False
# azureml_globaldatasets - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 45 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 46 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 47 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 48 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 49 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 50 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 51 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 52 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create Compute

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "aml-clusters3004"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create a Pipeline for Batch Inferencing

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Overwriting batch_pipeline/batch_diabetes.py

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(pip_packages=['scikit-learn','azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'batch_prediction_pipeline').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [1fd6b1a5][b2535422-4d01-47b6-8b24-5bd8fd43556b], (This step will run and generate new outputs)
# Submitted PipelineRun bb4d8731-4eea-474e-9aa6-97663cdaa920
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/bb4d8731-4eea-474e-9aa6-97663cdaa920?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# PipelineRunId: bb4d8731-4eea-474e-9aa6-97663cdaa920
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/bb4d8731-4eea-474e-9aa6-97663cdaa920?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 3b75cbf6-aac2-445f-8ea5-c4115101a735
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/batch_prediction_pipeline/runs/3b75cbf6-aac2-445f-8ea5-c4115101a735?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/01/30 16:25:25 Downloading source code...
# 2021/01/30 16:25:28 Finished downloading source code
# 2021/01/30 16:25:29 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/30 16:25:29 Successfully set up Docker network: acb_default_network
# 2021/01/30 16:25:29 Setting up Docker configuration...
# 2021/01/30 16:25:30 Successfully set up Docker configuration
# 2021/01/30 16:25:30 Logging in to registry: 8da8af49ef35455fac410377e98ec653.azurecr.io
# 2021/01/30 16:25:31 Successfully logged into 8da8af49ef35455fac410377e98ec653.azurecr.io
# 2021/01/30 16:25:31 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/30 16:25:31 Scanning for dependencies...
# 2021/01/30 16:25:33 Successfully scanned dependencies
# 2021/01/30 16:25:33 Launching container with name: acb_step_0
# Sending build context to Docker daemon  65.02kB
#
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/15 : USER root
#  ---> Running in 1f03beca86c1
# Removing intermediate container 1f03beca86c1
#  ---> f6db9f905169
# Step 3/15 : RUN mkdir -p $HOME/.cache
# StepRun( batch-score-diabetes ) Status: Running
#  ---> Running in 72491c1b512a
# Removing intermediate container 72491c1b512a
#  ---> f27d352c91f2
# Step 4/15 : WORKDIR /
#  ---> Running in ce187010b406
# Removing intermediate container ce187010b406
#  ---> 3eea1073ab25
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> aa1819b939f6
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1adadb18392c
# Removing intermediate container 1adadb18392c
#  ---> 038f62b71e2f
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 73697e6143e1
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c65af1042032
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##1        |  21%
# python-3.6.2         | 27.0 MB   | #####2     |  53%
# python-3.6.2         | 27.0 MB   | #######8   |  79%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####8     |  59%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.19yyarr7.requirements.txt']
# Pip subprocess output:
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.1-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.21.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core
#   Downloading azureml_core-1.21.0.post1-py3-none-any.whl (2.1 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.9.0-py3-none-any.whl (39.4 MB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.21.0
#   Downloading azureml_dataset_runtime-1.21.0-py3-none-any.whl (3.5 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.5.0-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting pytz
#   Downloading pytz-2020.5-py2.py3-none-any.whl (510 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting docker
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.8.0a,>=1.7.0dev0
#   Downloading azureml_dataprep_rslex-1.7.0-cp36-cp36m-manylinux2010_x86_64.whl (8.5 MB)
# Collecting azureml-dataprep-native<30.0.0,>=29.0.0
#   Downloading azureml_dataprep_native-29.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core->-r /azureml-environment-setup/condaenv.19yyarr7.requirements.txt (line 3)) (2020.6.20)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.8.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.10.0-py2.py3-none-any.whl (125 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=5b924a6252085f6beee2bb8c64b73cdf5e6d13cfff9425981f9fcdf70fe004b8
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=145764291f22a75e7d2a8aeadc017cb17ed21c113390caa196b68bc4b87b8895
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=bad7c385fbffe34443b6aba6fa42e84a74eabe580df2cd67c1a52df3bce03f70
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: numpy, scipy, joblib, threadpoolctl, scikit-learn, json-logging-py, gunicorn, werkzeug, liac-arff, dill, six, python-dateutil, pytz, pandas, chardet, idna, urllib3, requests, pycparser, cffi, cryptography, PyJWT, adal, azureml-model-management-sdk, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-common, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-mgmt-containerregistry, ruamel.yaml.clib, ruamel.yaml, backports.weakref, backports.tempfile, contextlib2, azure-mgmt-resource, websocket-client, docker, pyasn1, pyopenssl, ndg-httpsclient, azure-mgmt-keyvault, azure-mgmt-storage, jmespath, jeepney, SecretStorage, pathspec, azure-graphrbac, azure-mgmt-authorization, azureml-core, configparser, distro, dotnetcore2, cloudpickle, msal, portalocker, msal-extensions, azure-core, azure-identity, azureml-dataprep-rslex, azureml-dataprep-native, fusepy, azureml-dataprep, pyarrow, azureml-dataset-runtime, applicationinsights, itsdangerous, MarkupSafe, Jinja2, click, flask, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.10.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.21.0.post1 azureml-dataprep-2.9.0 azureml-dataprep-native-29.0.0 azureml-dataprep-rslex-1.7.0 azureml-dataset-runtime-1.21.0 azureml-defaults-1.21.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.3.1 dill-0.3.3 distro-1.5.0 docker-4.4.1 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.4.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 joblib-1.0.0 json-logging-py-0.2 jsonpickle-1.5.0 liac-arff-2.5.0 msal-1.8.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.5 oauthlib-3.1.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2020.5 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 scikit-learn-0.24.1 scipy-1.5.4 six-1.15.0 threadpoolctl-2.1.0 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container c65af1042032
#  ---> 12ba35c2c2ee
# Step 9/15 : ENV PATH /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c/bin:$PATH
#  ---> Running in dfb201a114de
# Removing intermediate container dfb201a114de
#  ---> eeb2bd111233
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c
#  ---> Running in 0f0137851118
# Removing intermediate container 0f0137851118
#  ---> b1394da2822b
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_0d2c44fcbf994b7e881cd6e7891c081c/lib:$LD_LIBRARY_PATH
#  ---> Running in 6589abf6bcd9
# Removing intermediate container 6589abf6bcd9
#  ---> 865c586ec24b
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 47d8824dd9ca
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in eb2ce33a8882
# Removing intermediate container eb2ce33a8882
#  ---> 08b16ae94007
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 117100fab5ee
# Removing intermediate container 117100fab5ee
#  ---> 9e3fb1364993
# Step 15/15 : CMD ["bash"]
#  ---> Running in 1f7669babce0
# Removing intermediate container 1f7669babce0
#  ---> c8dad39e2f69
# Successfully built c8dad39e2f69
# Successfully tagged 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_67a7dc9fc2af4cc267f7500e00a360f8:latest
# 2021/01/30 16:28:18 Successfully executed container: acb_step_0
# 2021/01/30 16:28:18 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/30 16:28:18 Pushing image: 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_67a7dc9fc2af4cc267f7500e00a360f8:latest, attempt 1
# The push refers to repository [8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_67a7dc9fc2af4cc267f7500e00a360f8]
# 62cca9338c8a: Preparing
# d4323af8e520: Preparing
# c5b1506cebee: Preparing
# 046d95d64549: Preparing
# c4699358c6f1: Preparing
# 9f393044af32: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 088c5f014be3: Waiting
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# 9f393044af32: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# c4699358c6f1: Pushed
# c5b1506cebee: Pushed
# 046d95d64549: Pushed
# 62cca9338c8a: Pushed
# 9f393044af32: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# e342e7653d41: Pushed
# 1a1a19626b20: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
# 088c5f014be3: Pushed
# 0c7d6f1219f0: Pushed
# d4323af8e520: Pushed
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
# latest: digest: sha256:e6593de6669a4f20fa0a35ce96db4cdf5d9560903d12a1a42573d099d12354bb size: 4095
# 2021/01/30 16:30:12 Successfully pushed image: 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_67a7dc9fc2af4cc267f7500e00a360f8:latest
# 2021/01/30 16:30:12 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 166.553817)
# 2021/01/30 16:30:12 Populating digests for step ID: acb_step_0...
# 2021/01/30 16:30:14 Successfully populated digests for step ID: acb_step_0
# 2021/01/30 16:30:14 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 114.145939)
# 2021/01/30 16:30:14 The following dependencies were found:
# 2021/01/30 16:30:14
# - image:
#     registry: 8da8af49ef35455fac410377e98ec653.azurecr.io
#     repository: azureml/azureml_67a7dc9fc2af4cc267f7500e00a360f8
#     tag: latest
#     digest: sha256:e6593de6669a4f20fa0a35ce96db4cdf5d9560903d12a1a42573d099d12354bb
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: cm4 was successful after 4m51s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_09a8c5134039fb9c8bd28c5bbca518e005df0ba91783308a8d2807c0b43642dc_d.txt
# ========================================================================================================================
# 2021-01-30T16:34:55Z Starting output-watcher...
# 2021-01-30T16:34:55Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# ec2c061b6e79: Pulling fs layer
# 45be97372f16: Pulling fs layer
# 741ed879c2f2: Pulling fs layer
# dcb42b399f96: Pulling fs layer
# c5158f856775: Pulling fs layer
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# ec2c061b6e79: Waiting
# 45be97372f16: Waiting
# 741ed879c2f2: Waiting
# dcb42b399f96: Waiting
# c5158f856775: Waiting
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 45be97372f16: Verifying Checksum
# 45be97372f16: Download complete
# 741ed879c2f2: Verifying Checksum
# 741ed879c2f2: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# dcb42b399f96: Verifying Checksum
# dcb42b399f96: Download complete
# c5158f856775: Verifying Checksum
# c5158f856775: Download complete
# ec2c061b6e79: Verifying Checksum
# ec2c061b6e79: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# ec2c061b6e79: Pull complete
# 45be97372f16: Pull complete
# 741ed879c2f2: Pull complete
# dcb42b399f96: Pull complete
# c5158f856775: Pull complete
# Digest: sha256:96a223a2d683aab4b4f91719ba3f705a79883c430ca39e73845fd2ba36704f14
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# viennaglobal.azurecr.io/azureml/azureml_9d4fa30783fc98f2c7c7f19c6a312f30:latest
# 2021-01-30T16:35:33Z Check if container 3b75cbf6-aac2-445f-8ea5-c4115101a735 already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_09a8c5134039fb9c8bd28c5bbca518e005df0ba91783308a8d2807c0b43642dc_d.txt
# ===============================================================================================================
# [2021-01-30T16:35:55.261986] Entering job preparation.
# [2021-01-30T16:35:55.866882] Starting job preparation.
# [2021-01-30T16:35:55.866934] Extracting the control code.
# [2021-01-30T16:35:55.875522] Finished fetching and extracting the control code.
# [2021-01-30T16:35:55.875562] Not a master node. Skipping rest of the context managers.
# [2021-01-30T16:35:55.875574] Entering Data Context Managers in Sidecar
# [2021-01-30T16:35:55.876026] Running Sidecar prep cmd...
# [2021-01-30T16:35:55.912867] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735-setup
# [2021-01-30T16:35:55.914008] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-30T16:35:55.916849] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-30T16:35:55.928232] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:35:55.928812] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:35:55.929245] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# [2021-01-30T16:35:55.929802] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "enter_contexts"
# [2021-01-30T16:35:55.930356] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:58203
# [2021-01-30T16:35:55.930718] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "enter_contexts":
# {"host_secret": "7bccfe0c-919e-4c2a-9fe1-f7f05264e2e4", "task": "enter_contexts", "caller_session_id": "32b05def-0bef-45e2-a500-bcd28d2314a2", "context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"], "job_task_error_path": "/mnt/batch/tasks/workitems/400c1b81-c129-4657-9d74-e4acb974da62/job-1/3b75cbf6-aac2-445f-8_bf6deb38-84ed-47ea-a0ce-f5f6fbb50550/wd/runSpecialJobTask_error.json"}
# [2021-01-30T16:36:08.866539] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "enter_contexts": {"result": "success"}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.19.0 azureml-dataprep==2.6.4. Session id: a4c076ac-771e-4e08-ad73-ef4197320a48. Run id: 3b75cbf6-aac2-445f-8ea5-c4115101a735.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "54743496-0ab8-4adf-86d2-1550f1b47f8a",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='mymachinelearningws', subscription_id='5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056', resource_group='mymachinelearningrg')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# Acquired lockfile /tmp/3b75cbf6-aac2-445f-8ea5-c4115101a735-datastore.lock to downloading input data references
# [2021-01-30T16:36:06.708137] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-01-30T16:36:06.709916] DEBUG azureml.sidecar.task.enter_contexts: Added Keys: ['AZUREML_SIDECAR_PATHS_TO_BIND']
# [2021-01-30T16:36:06.710553] DEBUG azureml.sidecar.task.enter_contexts: Updated Keys: ['diabetes_batch', 'DIABETES_BATCH', 'AZUREML_DATAREFERENCE_diabetes_batch']
# [2021-01-30T16:36:06.711870] DEBUG azureml.sidecar.task.enter_contexts: Persisted env vars changed by ContextManagers
# [2021-01-30T16:36:06.712395] DEBUG azureml.sidecar.task.enter_contexts: Get File Access Control List for /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu
# [2021-01-30T16:36:08.738883] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/1.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.740190] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/10.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.741402] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/100.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.742533] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/11.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.743476] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/12.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.744388] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/13.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.745256] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/14.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.746321] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/15.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.747261] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/16.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.748186] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/17.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.750123] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/18.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.759393] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/19.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.760455] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/2.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.765073] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/20.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.766216] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/21.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.767366] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/22.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.768245] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/23.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.769166] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/24.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.770076] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/25.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.770990] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/26.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.771883] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/27.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.772818] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/28.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.773699] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/29.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.774601] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/3.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.775560] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/30.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.776416] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/31.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.777231] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/32.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.778049] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/33.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.778889] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/34.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.779717] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/35.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.780527] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/36.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.781343] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/37.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.782164] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/38.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.783279] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/39.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.784216] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/4.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.785034] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/40.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.785961] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/41.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.786784] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/42.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.787614] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/43.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.788436] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/44.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.789251] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/45.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.790255] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/46.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.791201] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/47.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.792255] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/48.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.793165] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/49.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.794185] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/5.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.795167] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/50.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.796001] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/51.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.797113] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/52.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.798084] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/53.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.799067] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/54.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.799884] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/55.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.800718] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/56.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.801561] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/57.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.802385] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/58.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.803218] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/59.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.804192] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/6.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.805031] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/60.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.805849] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/61.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.806751] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/62.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.807575] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/63.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.808400] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/64.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.809258] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/65.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.810072] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/66.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.810911] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/67.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:08.811729] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/68.csv, ACL: 0o777, owner: root, group: root
# ...
# [2021-01-30T16:36:08.855307] DEBUG azureml.sidecar.task.enter_contexts: File: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu/99.csv, ACL: 0o777, owner: root, group: root
# [2021-01-30T16:36:09.999252] Ran Sidecar prep cmd.
# [2021-01-30T16:36:09.999309] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/01/30 16:36:41 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/01/30 16:36:41 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-01-30T16:36:42.651448] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.21.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 106
# Entering Run History Context Manager.
# [2021-01-30T16:36:45.399694] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:36:45.399914] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.21.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-01-30T16:36:45.400282] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.21.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/inferences', '--input_fds_0', 'diabetes_batch']
#
# Starting the daemon thread to refresh tokens in background for process with pid = 106
#
#
# [2021-01-30T16:37:38.216949] The experiment completed successfully. Finalizing run...
#
# Streaming azureml-logs/75_job_post-tvmps_d39d5ec0711ca7a4a40bbc8b9bba60907cde56d5e3651b58f617e40613467243_d.txt
# ===============================================================================================================
# [2021-01-30T16:37:46.082163] Entering job release
# [2021-01-30T16:37:47.360708] Starting job release
# [2021-01-30T16:37:47.361354] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 262
# [2021-01-30T16:37:47.362716] job release stage : upload_datastore starting...
# [2021-01-30T16:37:47.372332] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-01-30T16:37:47.373094] job release stage : execute_job_release starting...
# [2021-01-30T16:37:47.373441] job release stage : copy_batchai_cached_logs starting...
# [2021-01-30T16:37:47.374027] job release stage : copy_batchai_cached_logs completed...
# [2021-01-30T16:37:47.420479] Entering context manager injector.
# [2021-01-30T16:37:47.569740] job release stage : send_run_telemetry starting...
# [2021-01-30T16:37:47.583298] job release stage : upload_datastore completed...
# [2021-01-30T16:37:47.750604] job release stage : execute_job_release completed...
# [2021-01-30T16:37:48.156731] job release stage : send_run_telemetry completed...
# [2021-01-30T16:37:48.157108] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-01-30T16:37:48.157237] Running Sidecar release cmd...
# [2021-01-30T16:37:48.164698] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735-setup
# [2021-01-30T16:37:48.172929] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-30T16:37:48.173654] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-30T16:37:48.177105] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:37:48.177640] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:37:48.178467] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "exit_contexts"
# [2021-01-30T16:37:48.179130] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:41235
# [2021-01-30T16:37:48.179658] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "exit_contexts":
# {"host_secret": "0d1b1f98-3093-4750-beea-b9c9658b4142", "task": "exit_contexts", "caller_session_id": "b51174cb-e986-46f9-b8d1-73cd4d4008b6", "job_task_error_path": "/mnt/batch/tasks/workitems/400c1b81-c129-4657-9d74-e4acb974da62/job-1/3b75cbf6-aac2-445f-8_bf6deb38-84ed-47ea-a0ce-f5f6fbb50550/wd/runSpecialJobTask_error.json"}
# [2021-01-30T16:37:48.732480] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "exit_contexts": {"result": "success"}
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpyy0dqbke.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpyy0dqbke.
# Exit __exit__ of DatasetContextManager
# Removing absolute paths from host...
# [2021-01-30T16:37:48.722057] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-01-30T16:37:49.099853] Ran Sidecar release cmd.
# [2021-01-30T16:37:49.099926] Job release is complete
#
# Streaming azureml-logs/75_job_post-tvmps_09a8c5134039fb9c8bd28c5bbca518e005df0ba91783308a8d2807c0b43642dc_d.txt
# ===============================================================================================================
# [2021-01-30T16:37:46.438818] Entering job release
# [2021-01-30T16:37:47.391193] job release stage : copy_batchai_cached_logs starting...
# [2021-01-30T16:37:47.391491] job release stage : copy_batchai_cached_logs completed...
# [2021-01-30T16:37:47.391595] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-01-30T16:37:47.392113] Running Sidecar release cmd...
# [2021-01-30T16:37:47.398061] DEBUG azureml.sidecar.try_add_control_script_to_path: Adding ES Control Scripts to sys.path: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735-setup
# [2021-01-30T16:37:47.398934] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "enter_contexts"
# [2021-01-30T16:37:47.409464] DEBUG azureml.sidecar.TaskRegistry: Registering handler for task "exit_contexts"
# [2021-01-30T16:37:47.413286] DEBUG azureml.sidecar.set_run_wd: Changing working dir to: /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:37:47.413822] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/mounts/workspaceblobstore/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735
# [2021-01-30T16:37:47.414453] DEBUG azureml.sidecar.TaskRegistry.execute: Executing "exit_contexts"
# [2021-01-30T16:37:47.414923] DEBUG azureml.sidecar.TaskServerClient.__init__: Connecting to TaskServer at 127.0.0.1:58203
# [2021-01-30T16:37:47.415337] DEBUG azureml.sidecar.TaskRegistry.execute: Sending payload for "exit_contexts":
# {"host_secret": "7bccfe0c-919e-4c2a-9fe1-f7f05264e2e4", "task": "exit_contexts", "caller_session_id": "da5e7bcd-d547-4436-8045-c5907f681f95", "job_task_error_path": "/mnt/batch/tasks/workitems/400c1b81-c129-4657-9d74-e4acb974da62/job-1/3b75cbf6-aac2-445f-8_bf6deb38-84ed-47ea-a0ce-f5f6fbb50550/wd/runSpecialJobTask_error.json"}
# [2021-01-30T16:37:47.670633] DEBUG azureml.sidecar.TaskRegistry.execute: Received response for "exit_contexts": {"result": "success"}
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/wd/tmpwcsy74cu.
# Exit __exit__ of DatasetContextManager
# Removing absolute paths from host...
# [2021-01-30T16:37:47.656508] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-01-30T16:37:48.453447] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '3b75cbf6-aac2-445f-8ea5-c4115101a735', 'target': 'aml-clusters3004', 'status': 'Completed', 'startTimeUtc': '2021-01-30T16:34:41.754239Z', 'endTimeUtc': '2021-01-30T16:38:04.95544Z', 'properties': {'ContentSnapshotId': '2e40e7cf-5c3b-414e-a423-4b4ba64dba0c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'b2535422-4d01-47b6-8b24-5bd8fd43556b', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '1fd6b1a5', 'azureml.pipelinerunid': 'bb4d8731-4eea-474e-9aa6-97663cdaa920', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '54743496-0ab8-4adf-86d2-1550f1b47f8a'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.21.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-clusters3004', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/3b75cbf6-aac2-445f-8ea5-c4115101a735/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '54743496-0ab8-4adf-86d2-1550f1b47f8a', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-01-30T16:25:19Z_950d2b49', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['scikit-learn', 'azureml-defaults', 'azureml-core', 'azureml-dataprep[fuse]']}], 'name': 'azureml_0d2c44fcbf994b7e881cd6e7891c081c'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes':  ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'bb4d8731-4eea-474e-9aa6-97663cdaa920', 'status': 'Completed', 'startTimeUtc': '2021-01-30T16:24:06.293297Z', 'endTimeUtc': '2021-01-30T16:38:16.249075Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.bb4d8731-4eea-474e-9aa6-97663cdaa920/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=YLajEJo51tg3No8t7JQlMkLzgzmR0kddjtWCtAguMJc%3D&st=2021-01-30T16%3A28%3A17Z&se=2021-01-31T00%3A38%3A17Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.bb4d8731-4eea-474e-9aa6-97663cdaa920/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=WEfOuz7YMkj97qw3iIb4PdwdGJyxUUFDeH0nhUt1xIQ%3D&st=2021-01-30T16%3A28%3A17Z&se=2021-01-31T00%3A38%3A17Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.bb4d8731-4eea-474e-9aa6-97663cdaa920/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=kpca2fILOlgw3DyGArOeH8K37yYdHJ6nVgPjpUWBnmA%3D&st=2021-01-30T16%3A28%3A17Z&se=2021-01-31T00%3A38%3A17Z&sp=r'}, 'submittedBy': 'Tissana Tanaklang'}
# 'Finished'

# %%
import pandas as pd
import shutil

shutil.rmtree('diabetes-results', ignore_errors=True)

prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')


for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0    18.csv           1
# 1    19.csv           1
# 2     2.csv           1
# 3    20.csv           0
# 4    21.csv           0
# 5    31.csv           0
# 6    32.csv           1
# 7    33.csv           1
# 8    34.csv           1
# 9    35.csv           0
# 10    1.csv           0
# 11   10.csv           0
# 12  100.csv           0
# 13   11.csv           1
# 14   12.csv           0
# 15   59.csv           0
# 16    6.csv           0
# 17   60.csv           0
# 18   61.csv           0
# 19   62.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='Diabetes_Parallel_Batch_Pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: Diabetes_Parallel_Batch_Pipeline,
# Id: f6edcb87-0c65-4006-b0db-78b85795c5bc,
# Status: Active,
# Endpoint: https://southeastasia.api.azureml.ms/pipelines/v1.0/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourceGroups/mymachinelearningrg/providers/Microsoft.MachineLearningServices/workspaces/mymachinelearningws/PipelineRuns/PipelineSubmit/f6edcb87-0c65-4006-b0db-78b85795c5bc)

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://southeastasia.api.azureml.ms/pipelines/v1.0/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourceGroups/mymachinelearningrg/providers/Microsoft.MachineLearningServices/workspaces/mymachinelearningws/PipelineRuns/PipelineSubmit/f6edcb87-0c65-4006-b0db-78b85795c5bc

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "Batch_Pipeline_via_REST"})
run_id = response.json()["Id"]
run_id
# Out:
# 'e1cffaa6-5a01-41b8-a7cf-a57aa5697100'

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["Batch_Pipeline_via_REST"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
import pandas as pd
import shutil

shutil.rmtree("diabetes-results", ignore_errors=True)

prediction_run = next(published_pipeline_run.get_children())
prediction_output = prediction_run.get_output_data("inferences")
prediction_output.download(local_path="diabetes-results")


for root, dirs, files in os.walk("diabetes-results"):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   13.csv           0
# 1   14.csv           0
# 2   15.csv           1
# 3   16.csv           0
# 4   17.csv           0
# 5   36.csv           1
# 6   37.csv           0
# 7   38.csv           1
# 8   39.csv           0
# 9    4.csv           0
# 10  27.csv           0
# 11  28.csv           1
# 12  29.csv           0
# 13   3.csv           1
# 14  30.csv           1
# 15  22.csv           0
# 16  23.csv           0
# 17  24.csv           0
# 18  25.csv           0
# 19  26.csv           0
