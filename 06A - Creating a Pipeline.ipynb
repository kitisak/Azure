# %% [markdown]
# # Create a Pipeline

# %% [markdown]
# ## Connect to your workspace

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.21.0 to work with mymachinelearningws

# %% [markdown]
# ## Prepare data

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Writing diabetes_pipeline/prep_diabetes.py

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Writing diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "aml-clusters3004"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
train_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
register_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [9aaec54e][efdef411-a4cb-411b-ab75-44c2563a4760], (This step will run and generate new outputs)
# Created step Train and Register Model [9c2ac10c][819f7fe6-de7a-405f-afc2-3964e782e138], (This step will run and generate new outputs)
# Submitted PipelineRun 294ddf77-21aa-4f6e-a33b-68a9f35a1589
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/294ddf77-21aa-4f6e-a33b-68a9f35a1589?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 294ddf77-21aa-4f6e-a33b-68a9f35a1589
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/294ddf77-21aa-4f6e-a33b-68a9f35a1589?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# PipelineRun Status: Running
#
#
# StepRunId: e611b856-14e4-42d0-9145-ea8aca7522a2
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-pipeline/runs/e611b856-14e4-42d0-9145-ea8aca7522a2?wsid=/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourcegroups/mymachinelearningrg/workspaces/mymachinelearningws
# StepRun( Prepare Data ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/01/30 15:38:56 Downloading source code...
# 2021/01/30 15:38:58 Finished downloading source code
# 2021/01/30 15:38:58 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/30 15:38:59 Successfully set up Docker network: acb_default_network
# 2021/01/30 15:38:59 Setting up Docker configuration...
# 2021/01/30 15:38:59 Successfully set up Docker configuration
# 2021/01/30 15:38:59 Logging in to registry: 8da8af49ef35455fac410377e98ec653.azurecr.io
# 2021/01/30 15:39:00 Successfully logged into 8da8af49ef35455fac410377e98ec653.azurecr.io
# 2021/01/30 15:39:00 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/30 15:39:00 Scanning for dependencies...
# 2021/01/30 15:39:01 Successfully scanned dependencies
# 2021/01/30 15:39:01 Launching container with name: acb_step_0
# Sending build context to Docker daemon  65.02kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/15 : USER root
#  ---> Running in d09c84d0bc05
# Removing intermediate container d09c84d0bc05
#  ---> 115e6020c8d4
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in f63585c275e0
# Removing intermediate container f63585c275e0
#  ---> 4fb6262af375
# Step 4/15 : WORKDIR /
#  ---> Running in ca1b3efbfefd
# Removing intermediate container ca1b3efbfefd
#  ---> c214457bd993
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
# StepRun( Prepare Data ) Status: Running
#  ---> 07897e33043a
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1d696b25b744
# Removing intermediate container 1d696b25b744
#  ---> 8e86c4cc7c8e
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 09a680a46008
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in c7372fa0980a
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | #######    |  71%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ###9       |  39%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #####2     |  52%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | #########3 |  94%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | 6          |   6%
# scipy-1.5.2          | 18.5 MB   | ##1        |  22%
# scipy-1.5.2          | 18.5 MB   | ###9       |  39%
# scipy-1.5.2          | 18.5 MB   | #####8     |  58%
# scipy-1.5.2          | 18.5 MB   | ########   |  80%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | #######9   |  79%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 4          |   5%
# qt-5.9.6             | 86.7 MB   | #3         |  14%
# qt-5.9.6             | 86.7 MB   | ##2        |  22%
# qt-5.9.6             | 86.7 MB   | ###        |  31%
# qt-5.9.6             | 86.7 MB   | ###9       |  40%
# qt-5.9.6             | 86.7 MB   | ####8      |  49%
# qt-5.9.6             | 86.7 MB   | #####6     |  56%
# qt-5.9.6             | 86.7 MB   | ######4    |  65%
# qt-5.9.6             | 86.7 MB   | #######2   |  73%
# qt-5.9.6             | 86.7 MB   | ########2  |  82%
# qt-5.9.6             | 86.7 MB   | #########2 |  92%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | #####5     |  56%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | #######    |  71%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######2    |  63%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #6         |  16%
# python-3.6.2         | 27.0 MB   | ####3      |  43%
# python-3.6.2         | 27.0 MB   | #######1   |  71%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 1          |   1%
# mkl-2019.4           | 204.1 MB  | 5          |   5%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #5         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##2        |  22%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ##9        |  30%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####1      |  41%
# mkl-2019.4           | 204.1 MB  | ####5      |  45%
# mkl-2019.4           | 204.1 MB  | ####9      |  50%
# mkl-2019.4           | 204.1 MB  | #####3     |  53%
# mkl-2019.4           | 204.1 MB  | #####7     |  57%
# mkl-2019.4           | 204.1 MB  | ######1    |  61%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######8    |  69%
# mkl-2019.4           | 204.1 MB  | #######2   |  72%
# mkl-2019.4           | 204.1 MB  | #######6   |  76%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | #########2 |  93%
# mkl-2019.4           | 204.1 MB  | #########6 |  97%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ######6    |  67%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ####5      |  45%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #5         |  16%
# icu-58.2             | 22.7 MB   | ###6       |  36%
# icu-58.2             | 22.7 MB   | ######4    |  64%
# icu-58.2             | 22.7 MB   | #########9 |  99%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.2tw_qs08.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.21.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.9.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-core~=1.21.0
#   Downloading azureml_core-1.21.0.post1-py3-none-any.whl (2.1 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.21.0
#   Downloading azureml_dataset_runtime-1.21.0-py3-none-any.whl (3.5 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<30.0.0,>=29.0.0
#   Downloading azureml_dataprep_native-29.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex<1.8.0a,>=1.7.0dev0
#   Downloading azureml_dataprep_rslex-1.7.0-cp36-cp36m-manylinux2010_x86_64.whl (8.5 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 1)) (2.8.1)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 1)) (1.15.0)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 1)) (2020.1)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.3-py2.py3-none-any.whl (137 kB)
# Collecting docker
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.5.0-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.10.0-py2.py3-none-any.whl (125 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.8.0-py2.py3-none-any.whl (58 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib/python3.6/site-packages (from requests>=2.17.3->azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.2tw_qs08.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=5e5636220b05f3adf292d78643af88639662319e7f2493450ebc66465ebe6a79
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=1cbe995a86a3d8cf3bff3b37b6fabc90ba02e0524fcd012cab47a77ea8ef7ea1
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=5b09b049acf5b0598e16e0b7dce750a63ad0dfddfe115c6bd46ce1149e44b57f
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: pycparser, cffi, cryptography, PyJWT, urllib3, chardet, idna, requests, adal, dill, liac-arff, azureml-model-management-sdk, websocket-client, docker, ruamel.yaml.clib, ruamel.yaml, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-graphrbac, azure-mgmt-containerregistry, contextlib2, azure-mgmt-resource, pyopenssl, pathspec, pyasn1, ndg-httpsclient, jmespath, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-mgmt-keyvault, backports.weakref, backports.tempfile, azure-mgmt-storage, jeepney, SecretStorage, azure-mgmt-authorization, azureml-core, configparser, itsdangerous, click, MarkupSafe, Jinja2, werkzeug, flask, applicationinsights, azure-core, msal, portalocker, msal-extensions, azure-identity, distro, dotnetcore2, azureml-dataprep-native, azureml-dataprep-rslex, cloudpickle, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, json-logging-py, gunicorn, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.10.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.21.0.post1 azureml-dataprep-2.9.0 azureml-dataprep-native-29.0.0 azureml-dataprep-rslex-1.7.0 azureml-dataset-runtime-1.21.0 azureml-defaults-1.21.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.3.1 dill-0.3.3 distro-1.5.0 docker-4.4.1 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.4.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.5.0 liac-arff-2.5.0 msal-1.8.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.3 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
#  ---> 0c6ceb7192b2
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/lib:$LD_LIBRARY_PATH
#  ---> Running in 4d37b6602732
# Removing intermediate container 4d37b6602732
#  ---> 419a159d7246
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 3f0e2a643d92
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 92b0213983bd
# Removing intermediate container 92b0213983bd
#  ---> 43d82e327516
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 8ee83dbd3d93
# Removing intermediate container 8ee83dbd3d93
#  ---> 5e0f85f7ffbd
# Step 15/15 : CMD ["bash"]
#  ---> Running in 57ff2ca48434
# Removing intermediate container 57ff2ca48434
#  ---> 47ba7baf2058
# Successfully built 47ba7baf2058
# Successfully tagged 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7:latest
# 2021/01/30 15:44:11 Successfully executed container: acb_step_0
# 2021/01/30 15:44:11 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/30 15:44:11 Pushing image: 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7:latest, attempt 1
# The push refers to repository [8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7]
# ea42ac4c570a: Preparing
# adb094b2b511: Preparing
# a9f6983b4c17: Preparing
# 053f70df21b7: Preparing
# 370a01889e50: Preparing
# e9b2068e617f: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# 0c7d6f1219f0: Waiting
# e342e7653d41: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# da2785b7bb16: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# e9b2068e617f: Waiting
# a9f6983b4c17: Pushed
# ea42ac4c570a: Pushed
# 053f70df21b7: Pushed
# 370a01889e50: Pushed
# e9b2068e617f: Pushed
# c9fd473f5354: Pushed
# f449d8429d6e: Pushed
# cbb89d0b53de: Pushed
#
# fc2b9863058f: Pushed
# e342e7653d41: Pushed
# 1a1a19626b20: Pushed
# 5b7dc8292d9b: Pushed
# 088c5f014be3: Pushed
# bbc674332e2e: Pushed
# 0c7d6f1219f0: Pushed
# 8547178b7afb: Pushed
# da2785b7bb16: Pushed
# adb094b2b511: Pushed
# latest: digest: sha256:82339064d9e7df703b77ab154da759d8380d8ecc88ebd4ddb6d3f6012b59072d size: 4095
# 2021/01/30 15:47:08 Successfully pushed image: 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7:latest
# 2021/01/30 15:47:08 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 310.673933)
# 2021/01/30 15:47:08 Populating digests for step ID: acb_step_0...
# 2021/01/30 15:47:10 Successfully populated digests for step ID: acb_step_0
# 2021/01/30 15:47:10 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 177.349650)
# 2021/01/30 15:47:10 The following dependencies were found:
# 2021/01/30 15:47:10
# - image:
#     registry: 8da8af49ef35455fac410377e98ec653.azurecr.io
#     repository: azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7
#     tag: latest
#     digest: sha256:82339064d9e7df703b77ab154da759d8380d8ecc88ebd4ddb6d3f6012b59072d
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: cm2 was successful after 8m17s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# ========================================================================================================================
# 2021-01-30T15:50:51Z Starting output-watcher...
# 2021-01-30T15:50:51Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-01-30T15:50:52Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-01-30T15:50:52Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# c7805c3b913e: Pulling fs layer
# a3a8505a04fc: Pulling fs layer
# 114ed0a19c12: Pulling fs layer
# 04d973402b0a: Pulling fs layer
# 944a6ec6c9d1: Pulling fs layer
# 1c7f49767c8c: Pulling fs layer
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# c7805c3b913e: Waiting
# a3a8505a04fc: Waiting
# 114ed0a19c12: Waiting
# 04d973402b0a: Waiting
# 944a6ec6c9d1: Waiting
# 1c7f49767c8c: Waiting
# 05895bb28c18: Waiting
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# c7805c3b913e: Verifying Checksum
# c7805c3b913e: Download complete
# a3a8505a04fc: Verifying Checksum
# a3a8505a04fc: Download complete
# 114ed0a19c12: Verifying Checksum
# 114ed0a19c12: Download complete
# 04d973402b0a: Verifying Checksum
# 04d973402b0a: Download complete
# 1c7f49767c8c: Verifying Checksum
# 1c7f49767c8c: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 944a6ec6c9d1: Verifying Checksum
# 944a6ec6c9d1: Download complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# c7805c3b913e: Pull complete
# a3a8505a04fc: Pull complete
# 114ed0a19c12: Pull complete
# 04d973402b0a: Pull complete
# 944a6ec6c9d1: Pull complete
# 1c7f49767c8c: Pull complete
# Digest: sha256:82339064d9e7df703b77ab154da759d8380d8ecc88ebd4ddb6d3f6012b59072d
# Status: Downloaded newer image for 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7:latest
# 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7:latest
# 2021-01-30T15:52:18Z Check if container e611b856-14e4-42d0-9145-ea8aca7522a2 already exist exited with 0,
#
# 1fcaac68136f98344cefb976a3fad582d3752cff2b956f445dd737ea52fef7f7
# 2021/01/30 15:52:23 Starting App Insight Logger for task:  containerSetup
# 2021/01/30 15:52:23 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# 2021/01/30 15:52:23 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/01/30 15:52:23 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/01/30 15:52:23 sshd inside container not required for job, skipping setup.
# 2021/01/30 15:52:23 All App Insights Logs was send successfully
# 2021-01-30T15:52:23Z Starting docker container succeeded.
# 2021-01-30T15:52:27Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/01/30 15:50:48 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/01/30 15:50:48 Version: 3.0.01474.0002 Branch: .SourceBranch Commit: 407213b
# >>>   2021/01/30 15:50:48 runtime.GOOS linux
# >>>   2021/01/30 15:50:48 Reading dyanamic configs
# >>>   2021/01/30 15:50:48 Container sas url: https://baiscriptssg1prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=%2BZaEhC%2Fvslqn6L%2B0Mp1BIWPMJeRd2LPZmfZPloUDe4g%3D
# >>>   2021/01/30 15:50:48 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/01/30 15:50:48 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2021/01/30 15:50:48 azsecpack isEnable:false,GetDisableVsatlsscan:true
# >>>   2021/01/30 15:50:48 [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2021/01/30 15:50:48 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/01/30 15:50:48 DetonationChamber is not enabled on this subscription: 5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056
# >>>   2021/01/30 15:50:48 GPU count found: 0
# >>>   2021/01/30 15:50:48 AMLComputeXDSEndpoint:  https://sg1-prodk8ds.batchai.core.windows.net
# >>>   2021/01/30 15:50:48 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/01/30 15:50:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/config
# >>>   2021/01/30 15:50:48 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/01/30 15:50:48 Starting identity responder.
# >>>   2021/01/30 15:50:48 Starting identity responder.
# >>>   2021/01/30 15:50:48 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/01/30 15:50:48 Logfile used for identity responder: /mnt/batch/tasks/workitems/7ea33f78-895c-4b1a-b1a3-4b9379e5f2b0/job-1/e611b856-14e4-42d0-9_1bf05f16-f8ca-42da-9a16-7577b255f75d/IdentityResponderLog-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# >>>   2021/01/30 15:50:48 Logfile used for identity responder: /mnt/batch/tasks/workitems/7ea33f78-895c-4b1a-b1a3-4b9379e5f2b0/job-1/e611b856-14e4-42d0-9_1bf05f16-f8ca-42da-9a16-7577b255f75d/IdentityResponderLog-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# >>>   2021/01/30 15:50:48 Started Identity Responder for job.
# >>>   2021/01/30 15:50:48 Started Identity Responder for job.
# >>>   2021/01/30 15:50:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/wd
# >>>   2021/01/30 15:50:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/shared
# >>>   2021/01/30 15:50:48 Mounting job level file systems
# >>>   2021/01/30 15:50:48 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts
# >>>   2021/01/30 15:50:48 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/config/.amlcompute.datastorecredentials
# >>>   2021/01/30 15:50:48 Datastore credentials file not found, skipping.
# >>>   2021/01/30 15:50:48 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/config/.master.runtimesastokens
# >>>   2021/01/30 15:50:48 Runtime sas tokens file not found, skipping.
# >>>   2021/01/30 15:50:48 No NFS configured
# >>>   2021/01/30 15:50:48 No Azure File Shares configured
# >>>   2021/01/30 15:50:48 Mounting blob file systems
# >>>   2021/01/30 15:50:48 Blobfuse runtime version 1.3.6
# >>>   2021/01/30 15:50:48 Mounting azureml-blobstore-8da8af49-ef35-455f-ac41-0377e98ec653 container from mymachinelearn7523317901 account at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore
# >>>   2021/01/30 15:50:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/01/30 15:50:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/01/30 15:50:48 Blobfuse cache size set to 26638.32568359375 MB.
# >>>   2021/01/30 15:50:48 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=26638.32568359375 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/01/30 15:50:48 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore
# >>>   2021/01/30 15:50:48 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore
# >>>   2021/01/30 15:50:48 Successfully mounted azureml-blobstore-8da8af49-ef35-455f-ac41-0377e98ec653 container from mymachinelearn7523317901 account at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore
# >>>   2021/01/30 15:50:48 Mounting aml-data container from mystorageml3004 account at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/aml_data
# >>>   2021/01/30 15:50:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/01/30 15:50:48 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/01/30 15:50:48 Blobfuse cache size set to 26638.32568359375 MB.
# >>>   2021/01/30 15:50:48 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/aml_data --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/caches/aml_data --file-cache-timeout-in-seconds=1000000 --cache-size-mb=26638.32568359375 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/configs/aml_data.cfg --log-level=LOG_WARNING
# >>>   2021/01/30 15:50:48 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/aml_data
# >>>   2021/01/30 15:50:48 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/aml_data
# >>>   2021/01/30 15:50:49 Successfully mounted aml-data container from mystorageml3004 account at /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/aml_data
# >>>   2021/01/30 15:50:49 No unmanaged file systems configured
# >>>   2021/01/30 15:50:49 From the policy service, the filtering patterns is: , data store is
# >>>   2021/01/30 15:50:49 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/azureml_compute_logs
# >>>   2021/01/30 15:50:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/logs
# >>>   2021/01/30 15:50:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/mounts/workspaceblobstore/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/outputs
# >>>   2021/01/30 15:50:51 Starting output-watcher...
# >>>   2021/01/30 15:50:51 Single file input dataset is enabled.
# >>>   2021/01/30 15:50:51 Start to pulling docker image: 8da8af49ef35455fac410377e98ec653.azurecr.io/azureml/azureml_8d93117c7699b7075433b3fa6f5ae7c7
# >>>   2021/01/30 15:50:51 Start pull docker image: 8da8af49ef35455fac410377e98ec653.azurecr.io
# >>>   2021/01/30 15:50:51 Container registry is ACR.
# >>>   2021/01/30 15:50:51 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/01/30 15:50:51 Getting ACR Credentials from EMS for environment diabetes-pipeline-env:1
# >>>   2021/01/30 15:50:51 Requesting XDS for registry details.
# >>>   2021/01/30 15:50:51 Attempt 1 of http call to https://sg1-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/5cf2cbc9-c5e4-4c53-b2e2-fc68a1b1a056/resourceGroups/mymachinelearningrg/workspaces/mymachinelearningws/clusters/aml-clusters3004/nodes/tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d?api-version=2018-02-01
# >>>   2021/01/30 15:50:52 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2021/01/30 15:50:52 Got container registry details from credentials service for registry address: 8da8af49ef35455fac410377e98ec653.azurecr.io.
# >>>   2021/01/30 15:50:52 Writing ACR Details to file...
# >>>   2021/01/30 15:50:52 Copying ACR Details file to worker nodes...
# >>>   2021/01/30 15:50:52 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/01/30 15:50:52 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/01/30 15:50:52 Successfully retrieved ACR Credentials from EMS.
# >>>   2021/01/30 15:50:52 EMS returned 8da8af49ef35455fac410377e98ec653.azurecr.io for environment diabetes-pipeline-env
# >>>   2021/01/30 15:50:52 start login to the docker registry
# >>>   2021/01/30 15:50:52 Successfully logged into the docker registry.
# >>>   2021/01/30 15:50:52 Start run pull docker image command
# >>>   2021/01/30 15:52:18 Pull docker image succeeded.
# >>>   2021/01/30 15:52:18 Pull docker image time: 1m26.714011592s
# >>>
# ...
# >>>   2021/01/30 15:53:50 Starting docker container succeeded.
# >>>   2021/01/30 15:53:50 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638/azureml_compute_logs
# >>>   2021/01/30 15:53:50 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"97e5b77b-0a16-4a65-9d19-96dbfe1b535d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/01/30 15:53:50 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638/azureml_compute_logs/65_job_prep-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# >>>   2021/01/30 15:53:50 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638/azureml_compute_logs/65_job_prep-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# >>>   2021/01/30 15:53:50 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/7ea33f78-895c-4b1a-b1a3-4b9379e5f2b0/job-1/976a8fe4-3493-455d-b_a21da286-8304-4d33-a346-9a942431467c/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638;/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"97e5b77b-0a16-4a65-9d19-96dbfe1b535d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/01/30 15:53:50 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/01/30 15:53:50 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t 976a8fe4-3493-455d-bf64-084a8da25638 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/7ea33f78-895c-4b1a-b1a3-4b9379e5f2b0/job-1/976a8fe4-3493-455d-b_a21da286-8304-4d33-a346-9a942431467c/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638;/azureml-envs/azureml_37123770cfa02a1fe00f423fa57ee472/bin/python /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"97e5b77b-0a16-4a65-9d19-96dbfe1b535d","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/01/30 15:53:54 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:51.100150] Entering job preparation.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:52.324836] Starting job preparation.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:52.324891] Extracting the control code.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:52.344284] fetching and extracting the control code on master node.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:52.344326] Starting extract_project.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:52.344391] Starting to extract zip file.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.004926] Finished extracting zip file.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.134366] Using urllib.request Python 3.0 or later
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.134451] Start fetching snapshots.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.134504] Start fetching snapshot.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.134523] Retrieving project from snapshot: 97e5b77b-0a16-4a65-9d19-96dbfe1b535d
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 48
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.488541] Finished fetching snapshot.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.488610] Finished fetching snapshots.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.488670] Finished extract_project.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.499439] Finished fetching and extracting the control code.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.502688] downloadDataStore - Download from datastores if requested.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.504881] Start run_history_prep.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:53.555466] Entering context manager injector.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: Acquired lockfile /tmp/976a8fe4-3493-455d-bf64-084a8da25638-datastore.lock to downloading input data references
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:54.497571] downloadDataStore completed
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:54.501082] Job preparation is complete.
# >>>   2021/01/30 15:53:54 runSpecialJobTask: preparation: [2021-01-30T15:53:54.501145] Running Context Managers in Sidecar complete.
# >>>   2021/01/30 15:53:55 All App Insights Logs was send successfully
# >>>   2021/01/30 15:53:55 Process Exiting with Code:  0
# >>>
# 2021-01-30T15:53:55Z 127.0.0.1 slots=2 max-slots=2
# 2021-01-30T15:53:55Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/01/30 15:53:55 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/01/30 15:53:55 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-01-30T15:53:56.984886] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/aml_data/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/prepped_data_folder'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 103
# Entering Run History Context Manager.
# [2021-01-30T15:53:59.828447] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/workspaceblobstore/azureml/976a8fe4-3493-455d-bf64-084a8da25638
# [2021-01-30T15:53:59.828829] Preparing to call script [train_diabetes.py] with arguments:['--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/aml_data/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/prepped_data_folder']
# [2021-01-30T15:53:59.829348] After variable expansion, calling script [train_diabetes.py] with arguments:['--training-folder', '/mnt/batch/tasks/shared/LS_root/jobs/mymachinelearningws/azureml/976a8fe4-3493-455d-bf64-084a8da25638/mounts/aml_data/azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/prepped_data_folder']
#
# Loading Data...
# Training a decision tree model...
# Accuracy: 0.8995555555555556
# AUC: 0.8849151611085108
# Saving model...
# Registering model...
# Registering model diabetes_model
# Starting the daemon thread to refresh tokens in background for process with pid = 103
#
#
# [2021-01-30T15:54:16.315972] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.1348435878753662 seconds
# [2021-01-30T15:54:16.778809] Finished context manager injector.
#
# Streaming azureml-logs/75_job_post-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt
# ===============================================================================================================
# [2021-01-30T15:54:18.447519] Entering job release
# [2021-01-30T15:54:19.465369] Starting job release
# [2021-01-30T15:54:19.470920] Logging experiment finalizing status in history service.
# [2021-01-30T15:54:19.471083] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 177
# [2021-01-30T15:54:19.471603] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-01-30T15:54:19.471640] job release stage : execute_job_release starting...
# [2021-01-30T15:54:19.481601] job release stage : copy_batchai_cached_logs starting...
# [2021-01-30T15:54:19.481669] job release stage : copy_batchai_cached_logs completed...
# [2021-01-30T15:54:19.482815] Entering context manager injector.
# [2021-01-30T15:54:19.706667] job release stage : send_run_telemetry starting...
# [2021-01-30T15:54:19.734507] job release stage : upload_datastore completed...
# [2021-01-30T15:54:19.814816] job release stage : execute_job_release completed...
# [2021-01-30T15:54:20.417654] job release stage : send_run_telemetry completed...
# [2021-01-30T15:54:20.418100] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '976a8fe4-3493-455d-bf64-084a8da25638', 'target': 'aml-clusters3004', 'status': 'Completed', 'startTimeUtc': '2021-01-30T15:53:47.20791Z', 'endTimeUtc': '2021-01-30T15:54:29.098207Z', 'properties': {'ContentSnapshotId': '97e5b77b-0a16-4a65-9d19-96dbfe1b535d', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '819f7fe6-de7a-405f-afc2-3964e782e138', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '9c2ac10c', 'azureml.pipelinerunid': '294ddf77-21aa-4f6e-a33b-68a9f35a1589', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-clusters3004', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'aml_data', 'mode': 'Mount', 'pathOnDataStore': 'azureml/e611b856-14e4-42d0-9145-ea8aca7522a2/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_37123770cfa02a1fe00f423fa57ee472'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.976a8fe4-3493-455d-bf64-084a8da25638/azureml-logs/55_azureml-execution-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_d.txt?sv=2019-02-02&sr=b&sig=c338mmD%2FkYXGKFqnEWo20sekX9t1V1sumkYFst0Kfuc%3D&st=2021-01-30T15%3A44%3A23Z&se=2021-01-30T23%3A54%3A23Z&sp=r', 'azureml-logs/65_job_prep-tvmps_8e0729d8394db4b2b901ceee5c27bf4a84413fa247080111399d105809f99bf9_ ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '294ddf77-21aa-4f6e-a33b-68a9f35a1589', 'status': 'Completed', 'startTimeUtc': '2021-01-30T15:38:40.021416Z', 'endTimeUtc': '2021-01-30T15:54:49.700997Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.294ddf77-21aa-4f6e-a33b-68a9f35a1589/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=e9RqhBDXsRNrLTXw8gaGUq%2B9cRHIFMyLN%2BzhHhsHIJA%3D&st=2021-01-30T15%3A29%3A06Z&se=2021-01-30T23%3A39%3A06Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.294ddf77-21aa-4f6e-a33b-68a9f35a1589/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=vFqJxy%2F82EGdJ5lpVfJkWjEdbDUGW7Slx%2F8a55YQ4%2Bs%3D&st=2021-01-30T15%3A29%3A06Z&se=2021-01-30T23%3A39%3A06Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mymachinelearn7523317901.blob.core.windows.net/azureml/ExperimentRun/dcid.294ddf77-21aa-4f6e-a33b-68a9f35a1589/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=Ta%2BoHUIwQA0bk9JscR%2F2RFBzrrZHmRgmze42ITKaYaA%3D&st=2021-01-30T15%3A29%3A06Z&se=2021-01-30T23%3A39%3A06Z&sp=r'}, 'submittedBy': 'Tissana Tanaklang'}
# 'Finished'

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8995555555555556
# 	 AUC : 0.8849151611085108
# 	 ROC : aml://artifactId/ExperimentRun/dcid.976a8fe4-3493-455d-bf64-084a8da25638/ROC_1612022042.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
# 	 AUC : 0.8849151611085108
# 	 Accuracy : 0.8995555555555556
#
#
# diabetes_model version: 5
# 	 Training context : Compute cluster
# 	 AUC : 0.8568336517132793
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 4
# 	 Training context : File dataset
# 	 AUC : 0.8568517900798176
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 3
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568595320655352
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8484357430717946
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774
#
#
# amlstudio-predict-diabetes version: 1
# 	 CreatedByAMLStudio : true
